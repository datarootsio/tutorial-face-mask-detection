# %%
import matplotlib.pyplot as plt
import pandas as pd
import cv2

# %%
fn = 'images/collected_data/cropped_faces/0_0.jpg'
img = cv2.imread(fn)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (112, 112)) 
preprocessed_img = keras.applications.mobilenet.preprocess_input(img)
preprocessed_img = preprocessed_img[np.newaxis, ...]
model = keras.models.load_model('models/best.h5')
pred = model.predict(preprocessed_img)

# %% [markdown]
# 0 means no mask, 1 means mask

# %%
print(f"prediction for example image: {pred[0][0]}")
# Out:
# prediction for example image: 1.0

# %%
plt.imshow(img)
